# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import pickle
from sklearn import tree
from os import listdir
from os.path import isfile, join
from sklearn.metrics import classification_report
from sklearn.metrics import recall_score

# %%
df = pd.read_csv("../data/heart_2020_cleaned_for_models.csv")
model_path = "../models/"
files = [f for f in listdir(model_path) if isfile(join(model_path, f))]
print(files)
# Out:
# ['AdaBoostClassifier.pkl', 'DecisionTreeClassifier.pkl', 'GradientBoostingClassifier.pkl', 'KNeighborsClassifier.pkl', 'LinearSVC.pkl', 'LogisticRegression.pkl', 'MLPClassifier.pkl', 'RandomForestClassifier.pkl', 'SGDClassifier.pkl', 'StackingClassifier.pkl', 'VotingClassifier.pkl']

# %%
df.head()
# Out:
#    Unnamed: 0  HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  \
# 0           0             0  16.60        1                0       0
# 1           1             0  20.34        0                0       1
# 2           2             0  26.58        1                0       0
# 3           3             0  24.21        0                0       0
# 4           4             0  23.71        0                0       0
#
#    PhysicalHealth  MentalHealth  DiffWalking  Sex  AgeCategory  Race  \
# 0             3.0          30.0            0    0            8     5
# 1             0.0           0.0            0    0           13     5
# 2            20.0          30.0            0    1           10     5
# 3             0.0           0.0            0    0           12     5
# 4            28.0           0.0            1    0            5     5
#
#    Diabetic  PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  \
# 0         2                 1          4        5.0       1              0
# 1         0                 1          4        7.0       0              0
# 2         2                 1          2        8.0       1              0
# 3         0                 0          3        6.0       0              0
# 4         0                 1          4        8.0       0              0
#
#    SkinCancer
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %%
y = df["HeartDisease"]
X = df.drop("HeartDisease", axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lst=[]
for f in files :
    model = pickle.load(open(model_path+f, 'rb'))
    predicted=model.predict(X_test)
    print("The model :", model)
    print(classification_report(y_test, predicted))
    recall = recall_score(y_test, predicted, average='macro')
    lst.append(recall)
# Out:
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator AdaBoostClassifier from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but AdaBoostClassifier was fitted without feature names
#   warnings.warn(
# The model : AdaBoostClassifier(n_estimators=150)
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96     58485
#            1       0.54      0.12      0.20      5474
#
#     accuracy                           0.92     63959
#    macro avg       0.73      0.56      0.58     63959
# weighted avg       0.89      0.92      0.89     63959
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# The model : DecisionTreeClassifier(max_depth=8, max_leaf_nodes=30)
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     58485
#            1       0.60      0.05      0.08      5474
#
#     accuracy                           0.92     63959
#    macro avg       0.76      0.52      0.52     63959
# weighted avg       0.89      0.92      0.88     63959
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator DummyClassifier from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator GradientBoostingClassifier from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(
# The model : GradientBoostingClassifier(n_estimators=200)
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96     58485
#            1       0.59      0.10      0.17      5474
#
#     accuracy                           0.92     63959
#    macro avg       0.76      0.55      0.56     63959
# weighted avg       0.89      0.92      0.89     63959
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator KNeighborsClassifier from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\OMEN\anaconda3\envs\cuda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
print(lst)

# %%
maxx = max(lst)
model= lst[lst.index(maxx)]

# %%
filename = './SelectedModel.pkl'
pickle.dump(model, open(filename, 'wb'))

# %%
import matplotlib.pyplot as plt
for f in files :
    model = pickle.load(open(model_path+f, 'rb'))
    predicted=model.predict(X_test)
    print("The model :", model)
    probas = model.predict_proba(X_test)
    print('auc=', metrics.roc_auc_score(y_test, probas[:,1]))
    fpr0, tpr0, _ = metrics.roc_curve(y_test, probas[:, 1])
    fig, ax = plt.subplots(1, 1, figsize=(4,4))
    ax.plot([0, 1], [0, 1], 'k--')
    ax.plot(fpr0, tpr0, label=model.classes_[0])
    ax.set_title('Courbe ROC -classifieur')
    ax.text(0.5, 0.3, "plus mauvais que\nle hasard dans\ncette zone")
    ax.set_xlabel("FPR")
    ax.set_ylabel("TPR");ax.legend();
# Out:
# The model : AdaBoostClassifier(n_estimators=150)
# auc= 0.8403698898146412
# The model : DecisionTreeClassifier(max_depth=8, max_leaf_nodes=30)
# auc= 0.8213625900081655
# The model : GradientBoostingClassifier(n_estimators=200)
# auc= 0.8453461647890983
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-085b0d786854> in <module>
#       2 for f in files :
#       3     model = pickle.load(open(model_path+f, 'rb'))
# ----> 4     predicted=model.predict(X_test)
#       5     print("The model :", model)
#       6     probas = model.predict_proba(X_test)
#
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     195         X = check_array(X, accept_sparse='csr')
#     196
# --> 197         neigh_dist, neigh_ind = self.kneighbors(X)
#     198         classes_ = self.classes_
#     199         _y = self._y
#
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     703                 kwds = self.effective_metric_params_
#     704
# --> 705             chunked_results = list(pairwise_distances_chunked(
#     706                 X, self._fit_X, reduce_func=reduce_func,
#     707                 metric=self.effective_metric_, n_jobs=n_jobs,
#
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1621         else:
#    1622             X_chunk = X[sl]
# -> 1623         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
#    1624                                      n_jobs=n_jobs, **kwds)
#    1625         if ((X is Y or Y is None)
#
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1788         func = partial(distance.cdist, metric=metric, **kwds)
#    1789
# -> 1790     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1791
#    1792
#
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1357
#    1358     if effective_n_jobs(n_jobs) == 1:
# -> 1359         return func(X, Y, **kwds)
#    1360
#    1361     # enforce a threading backend to prevent data communication overhead
#
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     312         # if dtype is already float64, no need to chunk and upcast
#     313         distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
# --> 314         distances += XX
#     315         distances += YY
#     316     np.maximum(distances, 0, out=distances)
#
# KeyboardInterrupt:

# %%
files.pop(4)
files
# Out:
# ['AdaBoostClassifier.pkl',
#  'DecisionTreeClassifier.pkl',
#  'GradientBoostingClassifier.pkl',
#  'KNeighborsClassifier.pkl',
#  'LogisticRegression.pkl',
#  'MLPClassifier.pkl',
#  'RandomForestClassifier.pkl',
#  'SGDClassifier.pkl',
#  'StackingClassifier.pkl',
#  'VotingClassifier.pkl']

# %%
fig, ax = plt.subplots(1, 1, figsize=(15,15))
for i in range(len(files)):
    model = pickle.load(open(model_path+files[i], 'rb'))
    predicted=model.predict(X_test)
    print("The model :", model)
    probas = model.predict_proba(X_test)
    print('auc=', metrics.roc_auc_score(y_test, probas[:,1]))
    fpr0, tpr0, _ = metrics.roc_curve(y_test, probas[:, 1])
    
    ax.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr0, tpr0, label=files[i])
    ax.set_title('Courbe ROC -classifieur')
    ax.text(0.5, 0.3, "plus mauvais que\nle hasard dans\ncette zone")
    ax.set_xlabel("FPR")
    ax.set_ylabel("TPR");
    ax.legend();
plt.show()
# Out:
# The model : AdaBoostClassifier(n_estimators=150)
# auc= 0.8403698898146412
# The model : DecisionTreeClassifier(max_depth=8, max_leaf_nodes=30)
# auc= 0.8213625900081655
# The model : GradientBoostingClassifier(n_estimators=200)
# auc= 0.8453461647890983
# The model : KNeighborsClassifier(n_neighbors=11)
# auc= 0.7853357878926797
# The model : LogisticRegression(max_iter=500)
# auc= 0.4429804937762416
# The model : MLPClassifier(max_iter=1000, random_state=0)
# auc= 0.5069200606095996
# The model : RandomForestClassifier()
# auc= 0.9773415888888779
# The model : SGDClassifier(loss='log', random_state=0)
# auc= 0.5061950553623076
# The model : StackingClassifier(estimators=[('SGD',
#                                 SGDClassifier(loss='log', random_state=0)),
#                                ('Tree', DecisionTreeClassifier(random_state=0)),
#                                ('KNN', KNeighborsClassifier(n_neighbors=2))],
#                    final_estimator=KNeighborsClassifier())
# auc= 0.9257177173930317
# The model : VotingClassifier(estimators=[('SGD', SGDClassifier(loss='log', random_state=0)),
#                              ('Tree', DecisionTreeClassifier(random_state=0)),
#                              ('KNN', KNeighborsClassifier(n_neighbors=2))])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-3a99284e1b1e> in <module>
#       4     predicted=model.predict(X_test)
#       5     print("The model :", model)
# ----> 6     probas = model.predict_proba(X_test)
#       7     print('auc=', metrics.roc_auc_score(y_test, probas[:,1]))
#       8     fpr0, tpr0, _ = metrics.roc_curve(y_test, probas[:, 1])
#
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_voting.py in predict_proba(self)
#     346         """
#     347         if self.voting == 'hard':
# --> 348             raise AttributeError("predict_proba is not available when"
#     349                                  " voting=%r" % self.voting)
#     350         return self._predict_proba
#
# AttributeError: predict_proba is not available when voting='hard'
